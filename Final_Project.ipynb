# %%
import pandas as pd
df = pd.read_csv('C:/Users/Alka Mishra/IBM_HR_data.csv', delimiter=',', encoding='UTF-8')
ad_df = pd.read_csv('C:/Users/Alka Mishra/adult.csv', delimiter=',', header = None, encoding='UTF-8')
ad_df.columns = ['Age', 'JobType', 'EmpID',
                      'EducationLevel', 'Level', 'MaritalStatus',
                      'JobPosition', 'MaritalStatus_Desc', 'Race',
                      'Gender', 'Column_1', 'Column_2',
                      'Column_3', 'Location', 'ExpectedSalary']
ad_df_age = ad_df[['Age', 'JobType', 'EducationLevel', 'Level', 'JobPosition', 'MaritalStatus', 'Location', 'Gender', 'ExpectedSalary']].sort_values(by='Age', ascending=True)
ad_df_age
# Out:
#        Age            JobType EducationLevel  Level         JobPosition  \
# 12318   17            Private           11th      7               Sales
# 6312    17            Private           11th      7               Sales
# 30927   17            Private           11th      7       Other-service
# 12787   17          Local-gov           11th      7        Adm-clerical
# 25755   17                  ?           11th      7                   ?
# 14475   17            Private           11th      7               Sales
# 23394   17            Private           10th      6       Other-service
# 12802   17            Private           10th      6               Sales
# 11925   17            Private           10th      6       Other-service
# 28770   17            Private        7th-8th      4               Sales
# 29992   17            Private           11th      7               Sales
# 30402   17                  ?           11th      7                   ?
# 27350   17                  ?           11th      7                   ?
# 1478    17            Private           11th      7        Adm-clerical
# 15350   17                  ?           10th      6                   ?
# 14514   17       Self-emp-inc           10th      6        Craft-repair
# 7451    17            Private           11th      7               Sales
# 25203   17            Private           12th      8               Sales
# 24861   17            Private           10th      6       Other-service
# 10295   17            Private           11th      7       Other-service
# 8352    17            Private           11th      7               Sales
# 28754   17            Private           11th      7   Handlers-cleaners
# 371     17            Private           11th      7       Other-service
# 15850   17            Private           11th      7               Sales
# 29982   17            Private           10th      6       Other-service
# 22857   17          Local-gov           12th      8        Adm-clerical
# 6874    17            Private           10th      6       Other-service
# 12838   17            Private           12th      8      Prof-specialty
# 10836   17            Private           11th      7       Other-service
# 26088   17            Private           11th      7   Handlers-cleaners
# ...    ...                ...            ...    ...                 ...
# 4109    90                  ?      Bachelors     13                   ?
# 10545   90            Private        HS-grad      9        Craft-repair
# 12975   90            Private           10th      6     Exec-managerial
# 5272    90            Private            9th      5        Adm-clerical
# 22220   90            Private      Bachelors     13      Prof-specialty
# 15356   90            Private        HS-grad      9    Transport-moving
# 24238   90                  ?        1st-4th      2                   ?
# 2303    90            Private   Some-college     10       Other-service
# 18277   90            Private      Bachelors     13               Sales
# 20610   90            Private        Masters     14      Prof-specialty
# 18725   90          Local-gov        HS-grad      9       Other-service
# 14159   90          Local-gov     Assoc-acdm     12        Adm-clerical
# 8806    90            Private    Prof-school     15      Prof-specialty
# 1040    90            Private        HS-grad      9       Other-service
# 6624    90            Private           11th      7        Craft-repair
# 31696   90                  ?        HS-grad      9                   ?
# 25303   90                  ?        7th-8th      4                   ?
# 18413   90            Private      Bachelors     13      Prof-specialty
# 11512   90            Private        HS-grad      9       Other-service
# 19212   90            Private   Some-college     10               Sales
# 8973    90            Private      Bachelors     13               Sales
# 11731   90                  ?        HS-grad      9                   ?
# 28463   90        Federal-gov        HS-grad      9        Craft-repair
# 11996   90            Private      Bachelors     13     Exec-managerial
# 15892   90            Private      Bachelors     13     Exec-managerial
# 24043   90   Self-emp-not-inc        HS-grad      9     Exec-managerial
# 32277   90            Private        HS-grad      9        Adm-clerical
# 5104    90            Private   Some-college     10       Other-service
# 8963    90                  ?        HS-grad      9                   ?
# 10210   90   Self-emp-not-inc   Some-college     10     Farming-fishing
#
#              MaritalStatus        Location   Gender ExpectedSalary
# 12318        Never-married   United-States   Female          <=50K
# 6312         Never-married   United-States     Male          <=50K
# 30927        Never-married   United-States     Male          <=50K
# 12787        Never-married   United-States   Female          <=50K
# 25755        Never-married   United-States     Male          <=50K
# 14475        Never-married   United-States   Female          <=50K
# 23394        Never-married   United-States   Female          <=50K
# 12802        Never-married   United-States   Female          <=50K
# 11925        Never-married   United-States   Female          <=50K
# 28770        Never-married   United-States     Male          <=50K
# 29992        Never-married   United-States   Female          <=50K
# 30402        Never-married   United-States   Female          <=50K
# 27350        Never-married   United-States   Female          <=50K
# 1478         Never-married   United-States   Female          <=50K
# 15350        Never-married   United-States   Female          <=50K
# 14514        Never-married   United-States     Male          <=50K
# 7451         Never-married   United-States   Female          <=50K
# 25203        Never-married   United-States   Female          <=50K
# 24861        Never-married   United-States     Male          <=50K
# 10295        Never-married   United-States   Female          <=50K
# 8352         Never-married   United-States   Female          <=50K
# 28754        Never-married   United-States     Male          <=50K
# 371          Never-married   United-States     Male          <=50K
# 15850        Never-married   United-States     Male          <=50K
# 29982        Never-married   United-States   Female          <=50K
# 22857        Never-married   United-States   Female          <=50K
# 6874         Never-married          Canada     Male          <=50K
# 12838        Never-married   United-States     Male          <=50K
# 10836        Never-married   United-States     Male          <=50K
# 26088        Never-married   United-States   Female          <=50K
# ...                    ...             ...      ...            ...
# 4109               Widowed   United-States   Female          <=50K
# 10545   Married-civ-spouse         Ecuador     Male           >50K
# 12975   Married-civ-spouse   United-States     Male          <=50K
# 5272         Never-married   United-States   Female          <=50K
# 22220        Never-married   United-States     Male          <=50K
# 15356              Widowed   United-States     Male          <=50K
# 24238              Widowed   United-States   Female          <=50K
# 2303         Never-married   United-States     Male          <=50K
# 18277   Married-civ-spouse               ?     Male          <=50K
# 20610   Married-civ-spouse   United-States   Female           >50K
# 18725   Married-civ-spouse   United-States     Male          <=50K
# 14159   Married-civ-spouse     Philippines     Male          <=50K
# 8806    Married-civ-spouse   United-States     Male           >50K
# 1040         Never-married   United-States   Female          <=50K
# 6624    Married-civ-spouse   United-States     Male          <=50K
# 31696   Married-civ-spouse   United-States     Male           >50K
# 25303            Separated   United-States   Female          <=50K
# 18413        Never-married   United-States   Female          <=50K
# 11512        Never-married   United-States   Female          <=50K
# 19212             Divorced   United-States   Female          <=50K
# 8973    Married-civ-spouse   United-States     Male           >50K
# 11731              Widowed   United-States     Male          <=50K
# 28463   Married-civ-spouse   United-States     Male          <=50K
# 11996        Never-married   United-States     Male          <=50K
# 15892   Married-civ-spouse         England   Female           >50K
# 24043        Never-married   United-States     Male          <=50K
# 32277              Widowed   United-States   Female          <=50K
# 5104         Never-married   United-States     Male          <=50K
# 8963               Widowed   United-States   Female          <=50K
# 10210   Married-civ-spouse   United-States     Male          <=50K
#
# [32561 rows x 9 columns]

# %%
ad_df_age.dtypes
ad_df_age_private = pd.DataFrame({'Count': ad_df_age.groupby(by='JobType')['JobType'].count()})
ad_df_age_private
# Out:
#                    Count
# JobType
#  ?                  1836
#  Federal-gov         960
#  Local-gov          2093
#  Never-worked          7
#  Private           22696
#  Self-emp-inc       1116
#  Self-emp-not-inc   2541
#  State-gov          1298
#  Without-pay          14

# %%
ad_df_age.dtypes
ad_df_age['JobType'] = ad_df_age['JobType'].str.strip()
ad_df_age['Location'] = ad_df_age['Location'].str.strip()
ad_df_age['Gender'] = ad_df_age['Gender'].str.strip()
ad_df_age['JobPosition'] = ad_df_age['JobPosition'].str.strip()
ad_df_private = ad_df_age[ad_df_age['JobType'] == 'Private']
ad_df_private_US = ad_df_private[ad_df_private['Location'] == 'United-States']
ad_df_private_US = ad_df_private_US[ad_df_private_US['Age'] <= 60]
ad_df_private_US
# Out:
#        Age  JobType EducationLevel  Level        JobPosition  \
# 12318   17  Private           11th      7              Sales
# 6312    17  Private           11th      7              Sales
# 30927   17  Private           11th      7      Other-service
# 14475   17  Private           11th      7              Sales
# 23394   17  Private           10th      6      Other-service
# 12802   17  Private           10th      6              Sales
# 11925   17  Private           10th      6      Other-service
# 28770   17  Private        7th-8th      4              Sales
# 29992   17  Private           11th      7              Sales
# 1478    17  Private           11th      7       Adm-clerical
# 7451    17  Private           11th      7              Sales
# 25203   17  Private           12th      8              Sales
# 24861   17  Private           10th      6      Other-service
# 10295   17  Private           11th      7      Other-service
# 8352    17  Private           11th      7              Sales
# 28754   17  Private           11th      7  Handlers-cleaners
# 371     17  Private           11th      7      Other-service
# 15850   17  Private           11th      7              Sales
# 29982   17  Private           10th      6      Other-service
# 12838   17  Private           12th      8     Prof-specialty
# 10836   17  Private           11th      7      Other-service
# 26088   17  Private           11th      7  Handlers-cleaners
# 21200   17  Private           10th      6      Other-service
# 30328   17  Private           10th      6  Handlers-cleaners
# 26640   17  Private           11th      7              Sales
# 14416   17  Private           10th      6  Handlers-cleaners
# 15423   17  Private           10th      6      Other-service
# 31864   17  Private           12th      8       Adm-clerical
# 18800   17  Private           10th      6              Sales
# 16735   17  Private           10th      6      Other-service
# ...    ...      ...            ...    ...                ...
# 13112   60  Private      Bachelors     13    Exec-managerial
# 19101   60  Private        HS-grad      9      Other-service
# 19831   60  Private        HS-grad      9       Tech-support
# 8385    60  Private        HS-grad      9      Other-service
# 29610   60  Private        7th-8th      4    Priv-house-serv
# 470     60  Private   Some-college     10     Prof-specialty
# 25710   60  Private           10th      6       Tech-support
# 29230   60  Private        HS-grad      9              Sales
# 15116   60  Private      Assoc-voc     11       Craft-repair
# 3030    60  Private        HS-grad      9  Machine-op-inspct
# 5409    60  Private        HS-grad      9              Sales
# 12345   60  Private           10th      6      Other-service
# 31015   60  Private      Bachelors     13    Exec-managerial
# 24385   60  Private   Some-college     10      Other-service
# 18595   60  Private      Assoc-voc     11       Tech-support
# 29262   60  Private        HS-grad      9      Other-service
# 16712   60  Private   Some-college     10              Sales
# 21263   60  Private        7th-8th      4       Craft-repair
# 26677   60  Private   Some-college     10  Machine-op-inspct
# 602     60  Private        7th-8th      4      Other-service
# 2956    60  Private      Bachelors     13    Exec-managerial
# 19849   60  Private      Doctorate     16     Prof-specialty
# 28969   60  Private   Some-college     10       Craft-repair
# 7354    60  Private     Assoc-acdm     12       Adm-clerical
# 5362    60  Private        HS-grad      9       Craft-repair
# 21761   60  Private        HS-grad      9    Protective-serv
# 27607   60  Private            9th      5  Machine-op-inspct
# 8179    60  Private        7th-8th      4      Other-service
# 13035   60  Private           12th      8       Adm-clerical
# 2236    60  Private        HS-grad      9       Tech-support
#
#                 MaritalStatus       Location  Gender ExpectedSalary
# 12318           Never-married  United-States  Female          <=50K
# 6312            Never-married  United-States    Male          <=50K
# 30927           Never-married  United-States    Male          <=50K
# 14475           Never-married  United-States  Female          <=50K
# 23394           Never-married  United-States  Female          <=50K
# 12802           Never-married  United-States  Female          <=50K
# 11925           Never-married  United-States  Female          <=50K
# 28770           Never-married  United-States    Male          <=50K
# 29992           Never-married  United-States  Female          <=50K
# 1478            Never-married  United-States  Female          <=50K
# 7451            Never-married  United-States  Female          <=50K
# 25203           Never-married  United-States  Female          <=50K
# 24861           Never-married  United-States    Male          <=50K
# 10295           Never-married  United-States  Female          <=50K
# 8352            Never-married  United-States  Female          <=50K
# 28754           Never-married  United-States    Male          <=50K
# 371             Never-married  United-States    Male          <=50K
# 15850           Never-married  United-States    Male          <=50K
# 29982           Never-married  United-States  Female          <=50K
# 12838           Never-married  United-States    Male          <=50K
# 10836           Never-married  United-States    Male          <=50K
# 26088           Never-married  United-States  Female          <=50K
# 21200           Never-married  United-States    Male          <=50K
# 30328           Never-married  United-States    Male          <=50K
# 26640           Never-married  United-States  Female          <=50K
# 14416           Never-married  United-States  Female          <=50K
# 15423           Never-married  United-States    Male          <=50K
# 31864           Never-married  United-States  Female          <=50K
# 18800      Married-civ-spouse  United-States  Female          <=50K
# 16735           Never-married  United-States  Female          <=50K
# ...                       ...            ...     ...            ...
# 13112      Married-civ-spouse  United-States    Male           >50K
# 19101      Married-civ-spouse  United-States  Female          <=50K
# 19831                Divorced  United-States  Female          <=50K
# 8385                  Widowed  United-States  Female          <=50K
# 29610               Separated  United-States  Female          <=50K
# 470             Never-married  United-States    Male           >50K
# 25710                 Widowed  United-States  Female          <=50K
# 29230      Married-civ-spouse  United-States    Male           >50K
# 15116                 Widowed  United-States  Female          <=50K
# 3030                  Widowed  United-States  Female          <=50K
# 5409                 Divorced  United-States  Female          <=50K
# 12345                Divorced  United-States  Female          <=50K
# 31015      Married-civ-spouse  United-States    Male           >50K
# 24385      Married-civ-spouse  United-States    Male          <=50K
# 18595      Married-civ-spouse  United-States    Male          <=50K
# 29262      Married-civ-spouse  United-States    Male          <=50K
# 16712                 Widowed  United-States  Female          <=50K
# 21263      Married-civ-spouse  United-States    Male          <=50K
# 26677   Married-spouse-absent  United-States    Male           >50K
# 602                  Divorced  United-States  Female          <=50K
# 2956       Married-civ-spouse  United-States    Male           >50K
# 19849           Never-married  United-States  Female           >50K
# 28969      Married-civ-spouse  United-States    Male           >50K
# 7354       Married-civ-spouse  United-States    Male          <=50K
# 5362       Married-civ-spouse  United-States    Male          <=50K
# 21761                Divorced  United-States    Male          <=50K
# 27607      Married-civ-spouse  United-States    Male          <=50K
# 8179                 Divorced  United-States    Male          <=50K
# 13035      Married-civ-spouse  United-States    Male          <=50K
# 2236       Married-civ-spouse  United-States  Female           >50K
#
# [19173 rows x 9 columns]

# %%
df_attrition_count = pd.DataFrame({'Count': df.groupby(by='Attrition')['Attrition'].count()})
df_attrition_count
# Out:
#            Count
# Attrition
# No          1233
# Yes          237

# %%
df_attrition_count_g = pd.DataFrame({'Count': df.groupby(by='Gender')['Gender'].count()})
df_attrition_count_g
# Out:
#         Count
# Gender
# Female    588
# Male      882

# %%
df_attrition_m = df[df['Gender'] == 'Male']
df_attrition_f = df[df['Gender'] == 'Female']
df_attrition_m_count = pd.DataFrame({'Count': df_attrition_m.groupby(by='Attrition')['Attrition'].count()})
df_attrition_m_count
# Out:
#            Count
# Attrition
# No           732
# Yes          150

# %%
df_attrition_f_count = pd.DataFrame({'Count': df_attrition_f.groupby(by='Attrition')['Attrition'].count()})
df_attrition_f_count
# Out:
#            Count
# Attrition
# No           501
# Yes           87

# %%
df_attrition_m_age = pd.DataFrame({'Count': df_attrition_m.groupby(by='Age')['Age'].count()})
df_attrition_m_age
# Out:
#      Count
# Age
# 18       4
# 19       5
# 20       5
# 21       7
# 22      11
# 23      13
# 24      15
# 25      20
# 26      25
# 27      26
# 28      36
# 29      39
# 30      34
# 31      41
# 32      38
# 33      34
# 34      44
# 35      51
# 36      40
# 37      32
# 38      31
# 39      26
# 40      33
# 41      25
# 42      30
# 43      18
# 44      23
# 45      24
# 46      18
# 47      10
# 48      12
# 49      12
# 50      21
# 51      12
# 52      11
# 53       9
# 54       3
# 55      18
# 56       7
# 57       4
# 58       8
# 59       4
# 60       3

# %%
df_attrition_f_age = pd.DataFrame({'Count': df_attrition_f.groupby(by='Age')['Age'].count()})
df_attrition_f_age
# Out:
#      Count
# Age
# 18       4
# 19       4
# 20       6
# 21       6
# 22       5
# 23       1
# 24      11
# 25       6
# 26      14
# 27      22
# 28      12
# 29      29
# 30      26
# 31      28
# 32      23
# 33      24
# 34      33
# 35      27
# 36      29
# 37      18
# 38      27
# 39      16
# 40      24
# 41      15
# 42      16
# 43      14
# 44      10
# 45      17
# 46      15
# 47      14
# 48       7
# 49      12
# 50       9
# 51       7
# 52       7
# 53      10
# 54      15
# 55       4
# 56       7
# 58       6
# 59       6
# 60       2

# %%
from pandas import DataFrame
   
Data = {'Age': df_attrition_f.groupby(by='Age')['Age'].mean(),
        'Values': df_attrition_f.groupby(by='Age')['Age'].count()
       }
  
df_plot = DataFrame(Data,columns=['Age','Values'])
df_new = df_plot.plot(x ='Age', y='Values', kind = 'line')
df_new

# %%
Data_m = {'Age': df_attrition_m.groupby(by='Age')['Age'].mean(),
        'Values': df_attrition_m.groupby(by='Age')['Age'].count()
       }
  
df_plot_m = DataFrame(Data_m,columns=['Age','Values'])
df_new_m = df_plot_m.plot(x ='Age', y='Values', kind = 'line')
df_new_m

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# 12     31        No      Travel_Rarely        670  Research & Development
# 13     34        No      Travel_Rarely       1346  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 15     29        No      Travel_Rarely       1389  Research & Development
# 16     32        No      Travel_Rarely        334  Research & Development
# 17     22        No         Non-Travel       1123  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 19     38        No      Travel_Rarely        371  Research & Development
# 20     24        No         Non-Travel        673  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# 23     21        No      Travel_Rarely        391  Research & Development
# 24     34       Yes      Travel_Rarely        699  Research & Development
# 25     53        No      Travel_Rarely       1282  Research & Development
# 26     32       Yes  Travel_Frequently       1125  Research & Development
# 27     42        No      Travel_Rarely        691                   Sales
# 28     44        No      Travel_Rarely        477  Research & Development
# 29     46        No      Travel_Rarely        705                   Sales
# ...   ...       ...                ...        ...                     ...
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1441   56        No         Non-Travel        667  Research & Development
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1445   41        No      Travel_Rarely        582  Research & Development
# 1446   34        No      Travel_Rarely        704                   Sales
# 1447   36        No         Non-Travel        301                   Sales
# 1448   41        No      Travel_Rarely        930                   Sales
# 1449   32        No      Travel_Rarely        529  Research & Development
# 1450   35        No      Travel_Rarely       1146         Human Resources
# 1451   38        No      Travel_Rarely        345                   Sales
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1454   45        No      Travel_Rarely        374                   Sales
# 1455   40        No      Travel_Rarely       1322  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1457   40        No      Travel_Rarely       1194  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                    1          2     Life Sciences              1
# 1                    8          1     Life Sciences              1
# 2                    2          2             Other              1
# 3                    3          4     Life Sciences              1
# 4                    2          1           Medical              1
# 5                    2          2     Life Sciences              1
# 6                    3          3           Medical              1
# 7                   24          1     Life Sciences              1
# 8                   23          3     Life Sciences              1
# 9                   27          3           Medical              1
# 10                  16          3           Medical              1
# 11                  15          2     Life Sciences              1
# 12                  26          1     Life Sciences              1
# 13                  19          2           Medical              1
# 14                  24          3     Life Sciences              1
# 15                  21          4     Life Sciences              1
# 16                   5          2     Life Sciences              1
# 17                  16          2           Medical              1
# 18                   2          4     Life Sciences              1
# 19                   2          3     Life Sciences              1
# 20                  11          2             Other              1
# 21                   9          4     Life Sciences              1
# 22                   7          4     Life Sciences              1
# 23                  15          2     Life Sciences              1
# 24                   6          1           Medical              1
# 25                   5          3             Other              1
# 26                  16          1     Life Sciences              1
# 27                   8          4         Marketing              1
# 28                   7          4           Medical              1
# 29                   2          4         Marketing              1
# ...                ...        ...               ...            ...
# 1440                 4          2     Life Sciences              1
# 1441                 1          4     Life Sciences              1
# 1442                 1          4           Medical              1
# 1443                 2          3     Life Sciences              1
# 1444                 7          2  Technical Degree              1
# 1445                28          4     Life Sciences              1
# 1446                28          3         Marketing              1
# 1447                15          4         Marketing              1
# 1448                 3          3     Life Sciences              1
# 1449                 2          3  Technical Degree              1
# 1450                26          4     Life Sciences              1
# 1451                10          2     Life Sciences              1
# 1452                 1          4     Life Sciences              1
# 1453                11          4         Marketing              1
# 1454                20          3     Life Sciences              1
# 1455                 2          4     Life Sciences              1
# 1456                18          4     Life Sciences              1
# 1457                 2          4           Medical              1
# 1458                 1          4     Life Sciences              1
# 1459                13          2             Other              1
# 1460                28          4           Medical              1
# 1461                28          3         Marketing              1
# 1462                24          1         Marketing              1
# 1463                 5          3           Medical              1
# 1464                 5          3             Other              1
# 1465                23          2           Medical              1
# 1466                 6          1           Medical              1
# 1467                 4          3     Life Sciences              1
# 1468                 2          3           Medical              1
# 1469                 8          3           Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# 5                  8  ...                         3            80
# 6                 10  ...                         1            80
# 7                 11  ...                         2            80
# 8                 12  ...                         2            80
# 9                 13  ...                         2            80
# 10                14  ...                         3            80
# 11                15  ...                         4            80
# 12                16  ...                         4            80
# 13                18  ...                         3            80
# 14                19  ...                         2            80
# 15                20  ...                         3            80
# 16                21  ...                         4            80
# 17                22  ...                         2            80
# 18                23  ...                         3            80
# 19                24  ...                         3            80
# 20                26  ...                         4            80
# 21                27  ...                         2            80
# 22                28  ...                         3            80
# 23                30  ...                         4            80
# 24                31  ...                         3            80
# 25                32  ...                         4            80
# 26                33  ...                         2            80
# 27                35  ...                         4            80
# 28                36  ...                         4            80
# 29                38  ...                         4            80
# ...              ...  ...                       ...           ...
# 1440            2025  ...                         2            80
# 1441            2026  ...                         1            80
# 1442            2027  ...                         2            80
# 1443            2031  ...                         1            80
# 1444            2032  ...                         4            80
# 1445            2034  ...                         3            80
# 1446            2035  ...                         4            80
# 1447            2036  ...                         1            80
# 1448            2037  ...                         3            80
# 1449            2038  ...                         4            80
# 1450            2040  ...                         3            80
# 1451            2041  ...                         3            80
# 1452            2044  ...                         4            80
# 1453            2045  ...                         1            80
# 1454            2046  ...                         3            80
# 1455            2048  ...                         4            80
# 1456            2049  ...                         4            80
# 1457            2051  ...                         2            80
# 1458            2052  ...                         4            80
# 1459            2053  ...                         1            80
# 1460            2054  ...                         2            80
# 1461            2055  ...                         2            80
# 1462            2056  ...                         1            80
# 1463            2057  ...                         2            80
# 1464            2060  ...                         4            80
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# 5                    0                  8                      2
# 6                    3                 12                      3
# 7                    1                  1                      2
# 8                    0                 10                      2
# 9                    2                 17                      3
# 10                   1                  6                      5
# 11                   0                 10                      3
# 12                   1                  5                      1
# 13                   1                  3                      2
# 14                   0                  6                      4
# 15                   1                 10                      1
# 16                   2                  7                      5
# 17                   2                  1                      2
# 18                   0                 31                      3
# 19                   0                  6                      3
# 20                   1                  5                      5
# 21                   0                 10                      4
# 22                   0                 13                      4
# 23                   0                  0                      6
# 24                   0                  8                      2
# 25                   1                 26                      3
# 26                   0                 10                      5
# 27                   1                 10                      2
# 28                   1                 24                      4
# 29                   0                 22                      2
# ...                ...                ...                    ...
# 1440                 3                 18                      3
# 1441                 1                 13                      2
# 1442                 3                  4                      3
# 1443                 0                 24                      2
# 1444                 1                 14                      4
# 1445                 1                 21                      3
# 1446                 2                  8                      2
# 1447                 1                 15                      4
# 1448                 1                 14                      5
# 1449                 0                  4                      4
# 1450                 0                  9                      2
# 1451                 1                 10                      1
# 1452                 2                 12                      3
# 1453                 1                  8                      2
# 1454                 0                  8                      3
# 1455                 0                  8                      2
# 1456                 2                 10                      2
# 1457                 3                 20                      2
# 1458                 1                  4                      5
# 1459                 1                 10                      2
# 1460                 0                  5                      3
# 1461                 1                 20                      3
# 1462                 1                 21                      2
# 1463                 0                 10                      2
# 1464                 0                  5                      2
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# 5                  2               7                  7
# 6                  2               1                  0
# 7                  3               1                  0
# 8                  3               9                  7
# 9                  2               7                  7
# 10                 3               5                  4
# 11                 3               9                  5
# 12                 2               5                  2
# 13                 3               2                  2
# 14                 3               4                  2
# 15                 3              10                  9
# 16                 2               6                  2
# 17                 2               1                  0
# 18                 3              25                  8
# 19                 3               3                  2
# 20                 2               4                  2
# 21                 3               5                  3
# 22                 3              12                  6
# 23                 3               0                  0
# 24                 3               4                  2
# 25                 2              14                 13
# 26                 3              10                  2
# 27                 3               9                  7
# 28                 3              22                  6
# 29                 2               2                  2
# ...              ...             ...                ...
# 1440               3               4                  2
# 1441               2              13                 12
# 1442               4               2                  2
# 1443               2              22                  6
# 1444               1              10                  9
# 1445               3              20                  7
# 1446               3               8                  7
# 1447               2              15                 12
# 1448               3               5                  4
# 1449               3               4                  2
# 1450               3               9                  0
# 1451               3              10                  7
# 1452               3               6                  3
# 1453               2               6                  3
# 1454               3               5                  3
# 1455               3               2                  2
# 1456               4              10                  2
# 1457               3               5                  3
# 1458               3               4                  3
# 1459               3               4                  3
# 1460               1               5                  4
# 1461               3               3                  2
# 1462               2              20                  9
# 1463               3               9                  4
# 1464               3               4                  2
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# 5                           3                     6
# 6                           0                     0
# 7                           0                     0
# 8                           1                     8
# 9                           7                     7
# 10                          0                     3
# 11                          0                     8
# 12                          4                     3
# 13                          1                     2
# 14                          0                     3
# 15                          8                     8
# 16                          0                     5
# 17                          0                     0
# 18                          3                     7
# 19                          1                     2
# 20                          1                     3
# 21                          0                     3
# 22                          2                    11
# 23                          0                     0
# 24                          1                     3
# 25                          4                     8
# 26                          6                     7
# 27                          4                     2
# 28                          5                    17
# 29                          2                     1
# ...                       ...                   ...
# 1440                        0                     2
# 1441                        1                     9
# 1442                        2                     2
# 1443                        4                    14
# 1444                        9                     8
# 1445                        0                    10
# 1446                        1                     7
# 1447                       11                    11
# 1448                        0                     4
# 1449                        1                     2
# 1450                        1                     7
# 1451                        1                     9
# 1452                        0                     1
# 1453                        0                     0
# 1454                        0                     1
# 1455                        2                     2
# 1456                        0                     2
# 1457                        0                     2
# 1458                        1                     1
# 1459                        0                     3
# 1460                        0                     4
# 1461                        2                     0
# 1462                        9                     6
# 1463                        1                     7
# 1464                        0                     0
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
ad_df_private_US
# Out:
#        Age  JobType EducationLevel  Level        JobPosition  \
# 12318   17  Private           11th      7              Sales
# 6312    17  Private           11th      7              Sales
# 30927   17  Private           11th      7      Other-service
# 14475   17  Private           11th      7              Sales
# 23394   17  Private           10th      6      Other-service
# 12802   17  Private           10th      6              Sales
# 11925   17  Private           10th      6      Other-service
# 28770   17  Private        7th-8th      4              Sales
# 29992   17  Private           11th      7              Sales
# 1478    17  Private           11th      7       Adm-clerical
# 7451    17  Private           11th      7              Sales
# 25203   17  Private           12th      8              Sales
# 24861   17  Private           10th      6      Other-service
# 10295   17  Private           11th      7      Other-service
# 8352    17  Private           11th      7              Sales
# 28754   17  Private           11th      7  Handlers-cleaners
# 371     17  Private           11th      7      Other-service
# 15850   17  Private           11th      7              Sales
# 29982   17  Private           10th      6      Other-service
# 12838   17  Private           12th      8     Prof-specialty
# 10836   17  Private           11th      7      Other-service
# 26088   17  Private           11th      7  Handlers-cleaners
# 21200   17  Private           10th      6      Other-service
# 30328   17  Private           10th      6  Handlers-cleaners
# 26640   17  Private           11th      7              Sales
# 14416   17  Private           10th      6  Handlers-cleaners
# 15423   17  Private           10th      6      Other-service
# 31864   17  Private           12th      8       Adm-clerical
# 18800   17  Private           10th      6              Sales
# 16735   17  Private           10th      6      Other-service
# ...    ...      ...            ...    ...                ...
# 13112   60  Private      Bachelors     13    Exec-managerial
# 19101   60  Private        HS-grad      9      Other-service
# 19831   60  Private        HS-grad      9       Tech-support
# 8385    60  Private        HS-grad      9      Other-service
# 29610   60  Private        7th-8th      4    Priv-house-serv
# 470     60  Private   Some-college     10     Prof-specialty
# 25710   60  Private           10th      6       Tech-support
# 29230   60  Private        HS-grad      9              Sales
# 15116   60  Private      Assoc-voc     11       Craft-repair
# 3030    60  Private        HS-grad      9  Machine-op-inspct
# 5409    60  Private        HS-grad      9              Sales
# 12345   60  Private           10th      6      Other-service
# 31015   60  Private      Bachelors     13    Exec-managerial
# 24385   60  Private   Some-college     10      Other-service
# 18595   60  Private      Assoc-voc     11       Tech-support
# 29262   60  Private        HS-grad      9      Other-service
# 16712   60  Private   Some-college     10              Sales
# 21263   60  Private        7th-8th      4       Craft-repair
# 26677   60  Private   Some-college     10  Machine-op-inspct
# 602     60  Private        7th-8th      4      Other-service
# 2956    60  Private      Bachelors     13    Exec-managerial
# 19849   60  Private      Doctorate     16     Prof-specialty
# 28969   60  Private   Some-college     10       Craft-repair
# 7354    60  Private     Assoc-acdm     12       Adm-clerical
# 5362    60  Private        HS-grad      9       Craft-repair
# 21761   60  Private        HS-grad      9    Protective-serv
# 27607   60  Private            9th      5  Machine-op-inspct
# 8179    60  Private        7th-8th      4      Other-service
# 13035   60  Private           12th      8       Adm-clerical
# 2236    60  Private        HS-grad      9       Tech-support
#
#                 MaritalStatus       Location  Gender ExpectedSalary
# 12318           Never-married  United-States  Female          <=50K
# 6312            Never-married  United-States    Male          <=50K
# 30927           Never-married  United-States    Male          <=50K
# 14475           Never-married  United-States  Female          <=50K
# 23394           Never-married  United-States  Female          <=50K
# 12802           Never-married  United-States  Female          <=50K
# 11925           Never-married  United-States  Female          <=50K
# 28770           Never-married  United-States    Male          <=50K
# 29992           Never-married  United-States  Female          <=50K
# 1478            Never-married  United-States  Female          <=50K
# 7451            Never-married  United-States  Female          <=50K
# 25203           Never-married  United-States  Female          <=50K
# 24861           Never-married  United-States    Male          <=50K
# 10295           Never-married  United-States  Female          <=50K
# 8352            Never-married  United-States  Female          <=50K
# 28754           Never-married  United-States    Male          <=50K
# 371             Never-married  United-States    Male          <=50K
# 15850           Never-married  United-States    Male          <=50K
# 29982           Never-married  United-States  Female          <=50K
# 12838           Never-married  United-States    Male          <=50K
# 10836           Never-married  United-States    Male          <=50K
# 26088           Never-married  United-States  Female          <=50K
# 21200           Never-married  United-States    Male          <=50K
# 30328           Never-married  United-States    Male          <=50K
# 26640           Never-married  United-States  Female          <=50K
# 14416           Never-married  United-States  Female          <=50K
# 15423           Never-married  United-States    Male          <=50K
# 31864           Never-married  United-States  Female          <=50K
# 18800      Married-civ-spouse  United-States  Female          <=50K
# 16735           Never-married  United-States  Female          <=50K
# ...                       ...            ...     ...            ...
# 13112      Married-civ-spouse  United-States    Male           >50K
# 19101      Married-civ-spouse  United-States  Female          <=50K
# 19831                Divorced  United-States  Female          <=50K
# 8385                  Widowed  United-States  Female          <=50K
# 29610               Separated  United-States  Female          <=50K
# 470             Never-married  United-States    Male           >50K
# 25710                 Widowed  United-States  Female          <=50K
# 29230      Married-civ-spouse  United-States    Male           >50K
# 15116                 Widowed  United-States  Female          <=50K
# 3030                  Widowed  United-States  Female          <=50K
# 5409                 Divorced  United-States  Female          <=50K
# 12345                Divorced  United-States  Female          <=50K
# 31015      Married-civ-spouse  United-States    Male           >50K
# 24385      Married-civ-spouse  United-States    Male          <=50K
# 18595      Married-civ-spouse  United-States    Male          <=50K
# 29262      Married-civ-spouse  United-States    Male          <=50K
# 16712                 Widowed  United-States  Female          <=50K
# 21263      Married-civ-spouse  United-States    Male          <=50K
# 26677   Married-spouse-absent  United-States    Male           >50K
# 602                  Divorced  United-States  Female          <=50K
# 2956       Married-civ-spouse  United-States    Male           >50K
# 19849           Never-married  United-States  Female           >50K
# 28969      Married-civ-spouse  United-States    Male           >50K
# 7354       Married-civ-spouse  United-States    Male          <=50K
# 5362       Married-civ-spouse  United-States    Male          <=50K
# 21761                Divorced  United-States    Male          <=50K
# 27607      Married-civ-spouse  United-States    Male          <=50K
# 8179                 Divorced  United-States    Male          <=50K
# 13035      Married-civ-spouse  United-States    Male          <=50K
# 2236       Married-civ-spouse  United-States  Female           >50K
#
# [19173 rows x 9 columns]

# %%
ad_df_private_US.loc[ad_df_private_US.JobPosition == "Adm-clerical", 'Education Field'] = "Human Resources"
ad_df_private_US.loc[ad_df_private_US.JobPosition == "Farming-fishing", 'Education Field'] = "Life Sciences"
ad_df_private_US.loc[(ad_df_private_US.JobPosition == "Machine-op-inspct") | (ad_df_private_US.JobPosition == "Tech-support"), 'Education Field'] = "Technical Degree"
ad_df_private_US.loc[(ad_df_private_US.JobPosition == "Other-service") | (ad_df_private_US.JobPosition == "Transport-moving") | (ad_df_private_US.JobPosition == "Handlers-cleaners"), 'Education Field'] = "Other"
ad_df_private_US.loc[(ad_df_private_US.JobPosition == "Protective-serv") | (ad_df_private_US.JobPosition == "Prof-specialty"), 'Education Field'] = "Medical"
ad_df_private_US.loc[ad_df_private_US.JobPosition == "Sales", 'Education Field'] = "Management"
ad_df_private_US
# Out:
#        Age  JobType EducationLevel  Level        JobPosition  \
# 12318   17  Private           11th      7              Sales
# 6312    17  Private           11th      7              Sales
# 30927   17  Private           11th      7      Other-service
# 14475   17  Private           11th      7              Sales
# 23394   17  Private           10th      6      Other-service
# 12802   17  Private           10th      6              Sales
# 11925   17  Private           10th      6      Other-service
# 28770   17  Private        7th-8th      4              Sales
# 29992   17  Private           11th      7              Sales
# 1478    17  Private           11th      7       Adm-clerical
# 7451    17  Private           11th      7              Sales
# 25203   17  Private           12th      8              Sales
# 24861   17  Private           10th      6      Other-service
# 10295   17  Private           11th      7      Other-service
# 8352    17  Private           11th      7              Sales
# 28754   17  Private           11th      7  Handlers-cleaners
# 371     17  Private           11th      7      Other-service
# 15850   17  Private           11th      7              Sales
# 29982   17  Private           10th      6      Other-service
# 12838   17  Private           12th      8     Prof-specialty
# 10836   17  Private           11th      7      Other-service
# 26088   17  Private           11th      7  Handlers-cleaners
# 21200   17  Private           10th      6      Other-service
# 30328   17  Private           10th      6  Handlers-cleaners
# 26640   17  Private           11th      7              Sales
# 14416   17  Private           10th      6  Handlers-cleaners
# 15423   17  Private           10th      6      Other-service
# 31864   17  Private           12th      8       Adm-clerical
# 18800   17  Private           10th      6              Sales
# 16735   17  Private           10th      6      Other-service
# ...    ...      ...            ...    ...                ...
# 13112   60  Private      Bachelors     13    Exec-managerial
# 19101   60  Private        HS-grad      9      Other-service
# 19831   60  Private        HS-grad      9       Tech-support
# 8385    60  Private        HS-grad      9      Other-service
# 29610   60  Private        7th-8th      4    Priv-house-serv
# 470     60  Private   Some-college     10     Prof-specialty
# 25710   60  Private           10th      6       Tech-support
# 29230   60  Private        HS-grad      9              Sales
# 15116   60  Private      Assoc-voc     11       Craft-repair
# 3030    60  Private        HS-grad      9  Machine-op-inspct
# 5409    60  Private        HS-grad      9              Sales
# 12345   60  Private           10th      6      Other-service
# 31015   60  Private      Bachelors     13    Exec-managerial
# 24385   60  Private   Some-college     10      Other-service
# 18595   60  Private      Assoc-voc     11       Tech-support
# 29262   60  Private        HS-grad      9      Other-service
# 16712   60  Private   Some-college     10              Sales
# 21263   60  Private        7th-8th      4       Craft-repair
# 26677   60  Private   Some-college     10  Machine-op-inspct
# 602     60  Private        7th-8th      4      Other-service
# 2956    60  Private      Bachelors     13    Exec-managerial
# 19849   60  Private      Doctorate     16     Prof-specialty
# 28969   60  Private   Some-college     10       Craft-repair
# 7354    60  Private     Assoc-acdm     12       Adm-clerical
# 5362    60  Private        HS-grad      9       Craft-repair
# 21761   60  Private        HS-grad      9    Protective-serv
# 27607   60  Private            9th      5  Machine-op-inspct
# 8179    60  Private        7th-8th      4      Other-service
# 13035   60  Private           12th      8       Adm-clerical
# 2236    60  Private        HS-grad      9       Tech-support
#
#                 MaritalStatus       Location  Gender ExpectedSalary  \
# 12318           Never-married  United-States  Female          <=50K
# 6312            Never-married  United-States    Male          <=50K
# 30927           Never-married  United-States    Male          <=50K
# 14475           Never-married  United-States  Female          <=50K
# 23394           Never-married  United-States  Female          <=50K
# 12802           Never-married  United-States  Female          <=50K
# 11925           Never-married  United-States  Female          <=50K
# 28770           Never-married  United-States    Male          <=50K
# 29992           Never-married  United-States  Female          <=50K
# 1478            Never-married  United-States  Female          <=50K
# 7451            Never-married  United-States  Female          <=50K
# 25203           Never-married  United-States  Female          <=50K
# 24861           Never-married  United-States    Male          <=50K
# 10295           Never-married  United-States  Female          <=50K
# 8352            Never-married  United-States  Female          <=50K
# 28754           Never-married  United-States    Male          <=50K
# 371             Never-married  United-States    Male          <=50K
# 15850           Never-married  United-States    Male          <=50K
# 29982           Never-married  United-States  Female          <=50K
# 12838           Never-married  United-States    Male          <=50K
# 10836           Never-married  United-States    Male          <=50K
# 26088           Never-married  United-States  Female          <=50K
# 21200           Never-married  United-States    Male          <=50K
# 30328           Never-married  United-States    Male          <=50K
# 26640           Never-married  United-States  Female          <=50K
# 14416           Never-married  United-States  Female          <=50K
# 15423           Never-married  United-States    Male          <=50K
# 31864           Never-married  United-States  Female          <=50K
# 18800      Married-civ-spouse  United-States  Female          <=50K
# 16735           Never-married  United-States  Female          <=50K
# ...                       ...            ...     ...            ...
# 13112      Married-civ-spouse  United-States    Male           >50K
# 19101      Married-civ-spouse  United-States  Female          <=50K
# 19831                Divorced  United-States  Female          <=50K
# 8385                  Widowed  United-States  Female          <=50K
# 29610               Separated  United-States  Female          <=50K
# 470             Never-married  United-States    Male           >50K
# 25710                 Widowed  United-States  Female          <=50K
# 29230      Married-civ-spouse  United-States    Male           >50K
# 15116                 Widowed  United-States  Female          <=50K
# 3030                  Widowed  United-States  Female          <=50K
# 5409                 Divorced  United-States  Female          <=50K
# 12345                Divorced  United-States  Female          <=50K
# 31015      Married-civ-spouse  United-States    Male           >50K
# 24385      Married-civ-spouse  United-States    Male          <=50K
# 18595      Married-civ-spouse  United-States    Male          <=50K
# 29262      Married-civ-spouse  United-States    Male          <=50K
# 16712                 Widowed  United-States  Female          <=50K
# 21263      Married-civ-spouse  United-States    Male          <=50K
# 26677   Married-spouse-absent  United-States    Male           >50K
# 602                  Divorced  United-States  Female          <=50K
# 2956       Married-civ-spouse  United-States    Male           >50K
# 19849           Never-married  United-States  Female           >50K
# 28969      Married-civ-spouse  United-States    Male           >50K
# 7354       Married-civ-spouse  United-States    Male          <=50K
# 5362       Married-civ-spouse  United-States    Male          <=50K
# 21761                Divorced  United-States    Male          <=50K
# 27607      Married-civ-spouse  United-States    Male          <=50K
# 8179                 Divorced  United-States    Male          <=50K
# 13035      Married-civ-spouse  United-States    Male          <=50K
# 2236       Married-civ-spouse  United-States  Female           >50K
#
#         Education Field
# 12318        Management
# 6312         Management
# 30927             Other
# 14475        Management
# 23394             Other
# 12802        Management
# 11925             Other
# 28770        Management
# 29992        Management
# 1478    Human Resources
# 7451         Management
# 25203        Management
# 24861             Other
# 10295             Other
# 8352         Management
# 28754             Other
# 371               Other
# 15850        Management
# 29982             Other
# 12838           Medical
# 10836             Other
# 26088             Other
# 21200             Other
# 30328             Other
# 26640        Management
# 14416             Other
# 15423             Other
# 31864   Human Resources
# 18800        Management
# 16735             Other
# ...                 ...
# 13112               NaN
# 19101             Other
# 19831  Technical Degree
# 8385              Other
# 29610               NaN
# 470             Medical
# 25710  Technical Degree
# 29230        Management
# 15116               NaN
# 3030   Technical Degree
# 5409         Management
# 12345             Other
# 31015               NaN
# 24385             Other
# 18595  Technical Degree
# 29262             Other
# 16712        Management
# 21263               NaN
# 26677  Technical Degree
# 602               Other
# 2956                NaN
# 19849           Medical
# 28969               NaN
# 7354    Human Resources
# 5362                NaN
# 21761           Medical
# 27607  Technical Degree
# 8179              Other
# 13035   Human Resources
# 2236   Technical Degree
#
# [19173 rows x 10 columns]

# %%
ad_df_private_US = ad_df_private_US.dropna(subset=['Education Field'])
ad_df_private_US = ad_df_private_US[ad_df_private_US['Age'] > 17]
ad_df_private_US = ad_df_private_US[ad_df_private_US['Age'] <= 60]
ad_df_private_US
# Out:
#        Age  JobType EducationLevel  Level        JobPosition  \
# 29146   18  Private           11th      7              Sales
# 31905   18  Private           12th      8      Other-service
# 5913    18  Private           11th      7      Other-service
# 10112   18  Private        HS-grad      9              Sales
# 9644    18  Private   Some-college     10              Sales
# 29721   18  Private   Some-college     10      Other-service
# 21534   18  Private           12th      8  Handlers-cleaners
# 31935   18  Private           11th      7              Sales
# 787     18  Private           12th      8  Machine-op-inspct
# 1560    18  Private           12th      8  Handlers-cleaners
# 12388   18  Private        HS-grad      9       Adm-clerical
# 12645   18  Private        HS-grad      9      Other-service
# 30136   18  Private           11th      7      Other-service
# 3496    18  Private           11th      7      Other-service
# 16084   18  Private   Some-college     10      Other-service
# 27688   18  Private           11th      7              Sales
# 22229   18  Private           11th      7  Handlers-cleaners
# 30056   18  Private        HS-grad      9      Other-service
# 10022   18  Private           11th      7              Sales
# 16293   18  Private           12th      8       Adm-clerical
# 8284    18  Private        HS-grad      9              Sales
# 7251    18  Private           11th      7  Handlers-cleaners
# 16940   18  Private           11th      7      Other-service
# 31916   18  Private            9th      5      Other-service
# 5850    18  Private           10th      6      Other-service
# 25788   18  Private           11th      7      Other-service
# 10439   18  Private        HS-grad      9  Machine-op-inspct
# 31459   18  Private           11th      7              Sales
# 9990    18  Private           12th      8      Other-service
# 19703   18  Private           11th      7      Other-service
# ...    ...      ...            ...    ...                ...
# 4842    60  Private        HS-grad      9              Sales
# 25273   60  Private        7th-8th      4  Handlers-cleaners
# 6117    60  Private        HS-grad      9  Machine-op-inspct
# 31685   60  Private        HS-grad      9       Adm-clerical
# 26260   60  Private   Some-college     10  Handlers-cleaners
# 19795   60  Private     Assoc-acdm     12              Sales
# 21814   60  Private           11th      7    Protective-serv
# 16067   60  Private        HS-grad      9      Other-service
# 19101   60  Private        HS-grad      9      Other-service
# 19831   60  Private        HS-grad      9       Tech-support
# 8385    60  Private        HS-grad      9      Other-service
# 470     60  Private   Some-college     10     Prof-specialty
# 25710   60  Private           10th      6       Tech-support
# 29230   60  Private        HS-grad      9              Sales
# 3030    60  Private        HS-grad      9  Machine-op-inspct
# 5409    60  Private        HS-grad      9              Sales
# 12345   60  Private           10th      6      Other-service
# 24385   60  Private   Some-college     10      Other-service
# 18595   60  Private      Assoc-voc     11       Tech-support
# 29262   60  Private        HS-grad      9      Other-service
# 16712   60  Private   Some-college     10              Sales
# 26677   60  Private   Some-college     10  Machine-op-inspct
# 602     60  Private        7th-8th      4      Other-service
# 19849   60  Private      Doctorate     16     Prof-specialty
# 7354    60  Private     Assoc-acdm     12       Adm-clerical
# 21761   60  Private        HS-grad      9    Protective-serv
# 27607   60  Private            9th      5  Machine-op-inspct
# 8179    60  Private        7th-8th      4      Other-service
# 13035   60  Private           12th      8       Adm-clerical
# 2236    60  Private        HS-grad      9       Tech-support
#
#                 MaritalStatus       Location  Gender ExpectedSalary  \
# 29146           Never-married  United-States  Female          <=50K
# 31905           Never-married  United-States    Male          <=50K
# 5913            Never-married  United-States  Female          <=50K
# 10112           Never-married  United-States  Female          <=50K
# 9644            Never-married  United-States  Female          <=50K
# 29721           Never-married  United-States    Male          <=50K
# 21534           Never-married  United-States    Male          <=50K
# 31935           Never-married  United-States  Female          <=50K
# 787             Never-married  United-States    Male          <=50K
# 1560            Never-married  United-States    Male          <=50K
# 12388           Never-married  United-States  Female          <=50K
# 12645           Never-married  United-States    Male          <=50K
# 30136           Never-married  United-States    Male          <=50K
# 3496            Never-married  United-States    Male          <=50K
# 16084           Never-married  United-States    Male          <=50K
# 27688           Never-married  United-States  Female          <=50K
# 22229           Never-married  United-States    Male          <=50K
# 30056           Never-married  United-States  Female          <=50K
# 10022           Never-married  United-States  Female          <=50K
# 16293           Never-married  United-States  Female          <=50K
# 8284            Never-married  United-States    Male          <=50K
# 7251            Never-married  United-States    Male          <=50K
# 16940           Never-married  United-States  Female          <=50K
# 31916           Never-married  United-States    Male          <=50K
# 5850            Never-married  United-States    Male          <=50K
# 25788           Never-married  United-States  Female          <=50K
# 10439           Never-married  United-States  Female          <=50K
# 31459           Never-married  United-States    Male          <=50K
# 9990            Never-married  United-States  Female          <=50K
# 19703           Never-married  United-States    Male          <=50K
# ...                       ...            ...     ...            ...
# 4842                Separated  United-States  Female          <=50K
# 25273      Married-civ-spouse  United-States    Male          <=50K
# 6117       Married-civ-spouse  United-States    Male          <=50K
# 31685      Married-civ-spouse  United-States    Male          <=50K
# 26260      Married-civ-spouse  United-States    Male          <=50K
# 19795      Married-civ-spouse  United-States    Male          <=50K
# 21814                Divorced  United-States    Male          <=50K
# 16067   Married-spouse-absent  United-States  Female          <=50K
# 19101      Married-civ-spouse  United-States  Female          <=50K
# 19831                Divorced  United-States  Female          <=50K
# 8385                  Widowed  United-States  Female          <=50K
# 470             Never-married  United-States    Male           >50K
# 25710                 Widowed  United-States  Female          <=50K
# 29230      Married-civ-spouse  United-States    Male           >50K
# 3030                  Widowed  United-States  Female          <=50K
# 5409                 Divorced  United-States  Female          <=50K
# 12345                Divorced  United-States  Female          <=50K
# 24385      Married-civ-spouse  United-States    Male          <=50K
# 18595      Married-civ-spouse  United-States    Male          <=50K
# 29262      Married-civ-spouse  United-States    Male          <=50K
# 16712                 Widowed  United-States  Female          <=50K
# 26677   Married-spouse-absent  United-States    Male           >50K
# 602                  Divorced  United-States  Female          <=50K
# 19849           Never-married  United-States  Female           >50K
# 7354       Married-civ-spouse  United-States    Male          <=50K
# 21761                Divorced  United-States    Male          <=50K
# 27607      Married-civ-spouse  United-States    Male          <=50K
# 8179                 Divorced  United-States    Male          <=50K
# 13035      Married-civ-spouse  United-States    Male          <=50K
# 2236       Married-civ-spouse  United-States  Female           >50K
#
#         Education Field
# 29146        Management
# 31905             Other
# 5913              Other
# 10112        Management
# 9644         Management
# 29721             Other
# 21534             Other
# 31935        Management
# 787    Technical Degree
# 1560              Other
# 12388   Human Resources
# 12645             Other
# 30136             Other
# 3496              Other
# 16084             Other
# 27688        Management
# 22229             Other
# 30056             Other
# 10022        Management
# 16293   Human Resources
# 8284         Management
# 7251              Other
# 16940             Other
# 31916             Other
# 5850              Other
# 25788             Other
# 10439  Technical Degree
# 31459        Management
# 9990              Other
# 19703             Other
# ...                 ...
# 4842         Management
# 25273             Other
# 6117   Technical Degree
# 31685   Human Resources
# 26260             Other
# 19795        Management
# 21814           Medical
# 16067             Other
# 19101             Other
# 19831  Technical Degree
# 8385              Other
# 470             Medical
# 25710  Technical Degree
# 29230        Management
# 3030   Technical Degree
# 5409         Management
# 12345             Other
# 24385             Other
# 18595  Technical Degree
# 29262             Other
# 16712        Management
# 26677  Technical Degree
# 602               Other
# 19849           Medical
# 7354    Human Resources
# 21761           Medical
# 27607  Technical Degree
# 8179              Other
# 13035   Human Resources
# 2236   Technical Degree
#
# [13716 rows x 10 columns]
